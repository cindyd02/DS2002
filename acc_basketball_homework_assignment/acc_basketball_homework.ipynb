# %%
import pandas as pd

#1 reading the csv file
df = pd.read_csv('acc_players-2324F.csv', header=1)
df.head()
# Out:
#    Rk         Player Class Pos          School   G   MP  TRB  AST  STL  ...  \
# 0   1   Amaree Abram    SO   G    Georgia Tech  10  108   17   11    1  ...
# 1   2   Sola Adebisi    FR   F   Florida State   7    9    1    1    0  ...
# 2   3  Prince Aligbe    SO   F  Boston College  35  651  119   21   15  ...
# 3   4     Abe Atiyeh    SR   G  Boston College   4    6    0    0    0  ...
# 4   5    Zack Austin    JR   F      Pittsburgh  33  746  137   29   32  ...
#
#    TOV  PF  PTS    FG%    2P%    3P%    FT%   PER   WS  BPM
# 0    9  10   34  0.262  0.318  0.200  0.615   4.1 -0.1 -6.4
# 1    1   1    2  0.500  0.500    NaN    NaN   3.5  0.0 -6.7
# 2   30  51  164  0.435  0.522  0.147  0.620   9.4  0.9 -1.3
# 3    1   0    3  0.333  0.000  1.000    NaN   1.1  0.0 -8.2
# 4   13  35  216  0.417  0.563  0.295  0.737  18.0  2.9  7.9
#
# [5 rows x 21 columns]

# %%
# 2 basic analysis
total_points = df['PTS'].sum()
print(f'Total points scored by all players combined: {total_points}', 'points', '\n')

most_minutes_player = df.loc[df['MP'].idxmax()]
print(f'Player with the most minutes: {most_minutes_player["Player"]}', '\n')

top_5_rebounders = df.nlargest(5, 'TRB')
print('Top 5 players in terms of total rebounds:')
print(top_5_rebounders[['Player', 'TRB']])
# Out:
# Total points scored by all players combined: 38411 points
#
# Player with the most minutes: Casey Morsell
#
# Top 5 players in terms of total rebounds:
#               Player  TRB
# 5      Armando Bacot  380
# 178  Ian Schieffelin  340
# 90   Harrison Ingram  327
# 44    Mohamed Diarra  311
# 149    Norchad Omier  309

# %%
# 3 player filtering
filtered_df = df[df['MP'] > 500]

highest_assists_player = filtered_df.loc[filtered_df['AST'].idxmax()]
print(f'Player with the highest total assists: {highest_assists_player["Player"]}', '\n')

top_3_assist_leads = filtered_df.nlargest(3, 'AST')
print('Top 3 Assist Leads in the League:')
print(top_3_assist_leads[['Player', 'AST']], '\n')

top_3_shot_blockers = filtered_df.nlargest(3, 'BLK')
print('Top 3 Shot Blockers:')
print(top_3_shot_blockers[['Player', 'BLK']], '\n')
# Out:
# Player with the highest total assists: Reece Beekman
#
# Top 3 Assist Leads in the League:
#              Player  AST
# 7     Reece Beekman  212
# 215  Jaeden Zackery  152
# 21    Elliot Cadeau  150
#
# Top 3 Shot Blockers:
#             Player  BLK
# 51       Ryan Dunn   77
# 157   Quinten Post   61
# 5    Armando Bacot   56

# %%
# 4 school-based analysis
school_points = df.groupby('School')['PTS'].sum().reset_index()
print('Total points scored by each school:')
print(school_points, '\n')

school_assists = df.groupby('School')['AST'].sum().reset_index()
print('Total assists by each school:')
print(school_assists, '\n')

top_3_schools = school_points.nlargest(3, 'PTS')
print('Top 3 schools by total points scored:')
print(top_3_schools)
# Out:
# Total points scored by each school:
#             School   PTS
# 0   Boston College  2667
# 1          Clemson  2785
# 2             Duke  2830
# 3    Florida State  2526
# 4     Georgia Tech  2272
# 5       Louisville  2304
# 6       Miami (FL)  2424
# 7         NC State  3101
# 8   North Carolina  3032
# 9       Notre Dame  2113
# 10      Pittsburgh  2495
# 11        Syracuse  2442
# 12        Virginia  2140
# 13   Virginia Tech  2547
# 14     Wake Forest  2733
#
# Total assists by each school:
#             School  AST
# 0   Boston College  509
# 1          Clemson  533
# 2             Duke  551
# 3    Florida State  406
# 4     Georgia Tech  425
# 5       Louisville  356
# 6       Miami (FL)  454
# 7         NC State  536
# 8   North Carolina  536
# 9       Notre Dame  335
# 10      Pittsburgh  452
# 11        Syracuse  442
# 12        Virginia  509
# 13   Virginia Tech  514
# 14     Wake Forest  429
#
# Top 3 schools by total points scored:
#            School   PTS
# ...

# %%
# bonus 
import matplotlib.pyplot as plt

top_5_scorers = df.nlargest(5, 'PTS')
plt.bar(top_5_scorers['Player'], top_5_scorers['PTS'])
plt.xlabel('Player')
plt.ylabel('Total Points Scored')
plt.title('Top 5 Players by Total Points Scored')
plt.show()


plt.scatter(df['FG%'], df['WS'])
plt.xlabel('Field Goal Percentage (FG%)')
plt.ylabel('Win Shares (WS)')
plt.title('Correlation between FG% and WS')
plt.show()

correlation_coefficient = df['FG%'].corr(df['WS'])
print(f'Correlation coefficient between FG% and WS: {correlation_coefficient}')
# Out:
# Correlation coefficient between FG% and WS: 0.421066389419978

# %% [markdown]
# **Reflection**
#
# Working with CSV files and pandas DataFrames in this assignment has helped my data manipulation skills. I learned how to read CSV files into pandas DataFrames. Additionally, I developed techniques for filtering and manipulating data, such as calculating total points scored by players and identifying top players in terms of rebounds. These skills are important for future data analysis projects as they allow for efficient data handling and insightful analysis, enabling me to draw meaningful conclusions from large datasets.
#
# The most challenging aspect of this assignment was understanding the structure of the dataset. To overcome this, I spent time exploring the dataset, identifying necessary columns, and ensuring the data was in a usable format. This process taught me the the need for  attention to detail when preparing data for analysis.
#
# Analyzing ACC basketball statistics provided valuable insights that can be applied to other real-world datasets. The techniques used in this assignment, such as grouping data by categories, calculating aggregates, and visualizing relationships between variables, are applicable across various fields. This experience has prepared me for future data science challenges by demonstrating the power of data analysis in uncovering trends and patterns, ultimately aiding in decision-making processes.
